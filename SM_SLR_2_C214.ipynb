# %%
import numpy as np 
from sklearn.linear_model import LinearRegression as lgr

# %%
x=[61,63,67,69,70,74,76,81,86,91,95,97]
a=np.reshape(x,(-1,1))

# %%
y=[4280,4080,4420,4170,4480,4300,4820,4700,5110,5130,5640,5560]
b=np.reshape(y,(-1,1))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(a,b)
plt.show()

# %%
sns.residplot(y=a,x=b)
# Out:
# <AxesSubplot:>
